# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) seleção: PVLs dos municípios no estado do Rio de Janeiro

url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'

rj = requests.get(url)

rj.status_code
# Out:
# 200

# %%
# Seu código aqui
mun_rj = rj.json()
mun_rj
frame_rj = pd.DataFrame(mun_rj['items'])
frame_rj.head()
# Out:
#    id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0      12014        Município  Cardoso Moreira   3301157  RJ
# 1      11690        Município           Tanguá   3305752  RJ
# 2      13753        Município            Piraí   3304003  RJ
# 3      36529        Município          Resende   3304201  RJ
# 4      42476        Município      Nova Iguaçu   3303500  RJ
#
#                 num_pvl             status          num_processo  \
# 0                  None          Arquivado  17944.001581/2009-96
# 1                  None          Arquivado  17944.001503/2008-19
# 2                  None           Deferido  19405.000071/2002-58
# 3  PVL02.005421/2019-25  Deferido (PVL-IF)                  None
# 4  PVL02.001006/2020-36           Deferido  17944.101957/2020-77
#
#          data_protocolo                tipo_operacao  \
# 0  2010-05-07T03:00:00Z  Operação contratual interna
# 1  2008-11-04T02:00:00Z  Operação contratual interna
# ...

# %%
# 2) Quais são os três status das solicitações mais frequentes na base? Quais são suas frequências?

#frame_rj.info()
#frame_rj.status.unique()
frame_rj.status.value_counts() # aceita com [] ou sem
frame_rj['status'].value_counts()
# Out:
# Deferido                                                 91
# Arquivado                                                53
# Regularizado                                             25
# Arquivado por decurso de prazo                           23
# Deferido (PVL-IF)                                        16
# Encaminhado à PGFN com manifestação técnica favorável    13
# Arquivado a pedido                                        6
# Em retificação pelo interessado                           3
# Pendente de regularização                                 1
# Em análise                                                1
# Em retificação pelo interessado (PVL-IF)                  1
# Name: status, dtype: int64

# %%
# 3) Construa uma nova variável que contenha o ano do status

frame_rj['data_status'] = frame_rj['data_status'].astype(str) # convertendo para string

print(frame_rj['data_status'].dtype) # dtype não mostra string, mas converteu!

frame_rj['ano'] = frame_rj['data_status'].str[-4:] # uso do método slice [início:fim]

frame_rj.head()
# Out:
# object
#    id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0      12014        Município  Cardoso Moreira   3301157  RJ
# 1      11690        Município           Tanguá   3305752  RJ
# 2      13753        Município            Piraí   3304003  RJ
# 3      36529        Município          Resende   3304201  RJ
# 4      42476        Município      Nova Iguaçu   3303500  RJ
#
#                 num_pvl             status          num_processo  \
# 0                  None          Arquivado  17944.001581/2009-96
# 1                  None          Arquivado  17944.001503/2008-19
# 2                  None           Deferido  19405.000071/2002-58
# 3  PVL02.005421/2019-25  Deferido (PVL-IF)                  None
# 4  PVL02.001006/2020-36           Deferido  17944.101957/2020-77
#
#          data_protocolo                tipo_operacao  \
# 0  2010-05-07T03:00:00Z  Operação contratual interna
# 1  2008-11-04T02:00:00Z  Operação contratual interna
# ...

# %%
# 4) Indique a frequência de cada ano

frame_rj['ano'].value_counts()
# Out:
# 2008    37
# 2007    29
# 2014    20
# 2010    19
# 2019    17
# 2013    15
# 2020    15
# 2012    13
# 2022    12
# 2011    10
# 2009     9
# 2015     9
# 2017     5
# 2021     5
# 2002     4
# 2006     4
# 2016     4
# 2018     4
# 2004     1
# 2003     1
# Name: ano, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui

url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Munic%C3%ADpio'
url1 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado'  

uf_ba = requests.get(url)
uf_mg = requests.get(url1)

uf_ba.status_code
uf_mg.status_code

mun_ba = uf_ba.json()
est_mg = uf_mg.json()

mun_ba 
est_mg

munic_ba = pd.DataFrame(mun_ba['items'])
munic_ba.head(2)
# Out:
#    id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 0      30609        Município  Luís Eduardo Magalhães   2919553  BA
# 1      45855        Município                Ibirapuã   2912806  BA
#
#                 num_pvl             status          num_processo  \
# 0  PVL02.002969/2018-32           Deferido  17944.110232/2018-55
# 1  PVL02.001996/2021-93  Deferido (PVL-IF)                  None
#
#          data_protocolo                tipo_operacao      finalidade  \
# 0  2019-03-01T20:16:36Z  Operação contratual interna  Infraestrutura
# 1                  None  Operação contratual interna  Infraestrutura
#
#                        tipo_credor                   credor moeda  \
# 0  Instituição Financeira Nacional  Caixa Econômica Federal  Real
# 1  Instituição Financeira Nacional  Caixa Econômica Federal  Real
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  20656558.48                 0                      1  08/03/2019
# ...

# %%
estado_mg = pd.DataFrame(est_mg['items'])
estado_mg.head(2)
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl  \
# 0      13618           Estado  Minas Gerais        31  MG    None
# 1       7280           Estado  Minas Gerais        31  MG    None
#
#                                               status          num_processo  \
# 0  Encaminhado à PGFN com manifestação técnica fa...  19405.000037/2006-15
# 1                                           Deferido  17944.000537/2010-01
#
#          data_protocolo                                      tipo_operacao  \
# 0  2009-02-26T03:00:00Z  Operação contratual externa (com garantia da U...
# 1  2010-06-24T03:00:00Z                        Operação contratual interna
#
#        finalidade                           tipo_credor  \
# 0  Multissetorial  Instituição Financeira Internacional
# 1  Infraestrutura       Instituição Financeira Nacional
#
#                                               credor          moeda  \
# ...

# %%
# 2) Minas Gerais com status em 'Arquivado por decurso de prazo' estão registradas?

estado_mg['registradas'] = estado_mg['status'] == 'Arquivado por decurso de prazo'

estado_mg.registradas.value_counts()
# Out:
# False    39
# True      1
# Name: registradas, dtype: int64

# %%
# 3) Qual é o município da Bahia com mais solicitações deferidas?

munic_ba['deferidas'] = munic_ba['status'] == 'Deferido' 

munic_ba.loc[munic_ba['deferidas']]

municipios_deferidos = munic_ba.loc[munic_ba['deferidas']].copy()

municipios_deferidos.interessado.value_counts()
# Out:
# Luís Eduardo Magalhães    14
# Vitória da Conquista      11
# Camaçari                  10
# Lauro de Freitas          10
# Barreiras                  8
#                           ..
# Ubaitaba                   1
# Pedrão                     1
# Boa Vista do Tupim         1
# Taperoá                    1
# Andorinha                  1
# Name: interessado, Length: 173, dtype: int64

# %%
# 4) Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

url2 = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado'
ba1 = requests.get(url2)
ba1.status_code

est_ba1 = ba1.json()
est_ba1
frame_ba1 = pd.DataFrame(est_ba1['items'])


frame_ba1.to_csv('Solicitações da Bahia por Estado.csv')

frame_ba1.head(2)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl  \
# 0      10859           Estado       Bahia        29  BA    None
# 1      10855           Estado       Bahia        29  BA    None
#
#                                               status          num_processo  \
# 0                                           Deferido  17944.001302/2013-71
# 1  Encaminhado à PGFN com manifestação técnica fa...  17944.001301/2014-15
#
#          data_protocolo                                      tipo_operacao  \
# 0  2013-10-11T03:00:00Z                        Operação contratual interna
# 1  2016-03-17T03:00:00Z  Operação contratual externa (com garantia da U...
#
#                            finalidade                           tipo_credor  \
# 0  PAC 2 - Mobilidade Grandes Cidades       Instituição Financeira Nacional
# 1                      Infraestrutura  Instituição Financeira Internacional
#
#                                               credor          moeda  \
# ...

# %% [markdown]
# Prezado Tutor(a), não consegui fazer a função solicitada no exercício 1). Solicito orientações.
